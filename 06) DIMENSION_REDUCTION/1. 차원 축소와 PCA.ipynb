# %% [markdown]
# # 1. 차원 축소
# #### 차원 축소는 매우 많은 피처로 구성된 다차원 데이터 세트의 차원을 축소해 새로운 차원의 데이터 세트를 생성하는 것
# #### 차원이 증가할수록 여러 가지 문제(데이터 포인터 간 거리 증가, 희소한 구조, 예측 신뢰도 하락, 개별 피처간 상관관계 증가 -> 다중 공선성 문제)가 발생한다.
# #### 일반적으로 차원 축소는 피처 선택(feature selection)과 피처 추출(feature extraction)으로 나눌 수 있다.
# #### 피처 선택은 특정 피처에 종속성이 강한 불필요한 피처를 제거하고 데이터의 특징을 잘 나타내는 주요 피처만 선택하는 것
# #### 피처 추출은 기존 피처를 저차원의 중요 피처로 압축해서 추출하는 것, 새롭게 추출된 피처는 기존의 피처와는 완전히 다른 값이 된다.

# %% [markdown]
# #### 피처 추출은 기존 피처를 단순 압축이 아닌, 피처를 함축적으로 더 잘 설명할 수 있는 또 다른 공간으로 매핑해 추출하는 것
# #### 예를 들어, 학생을 평가하는 요소로 모의고사 성적, 내신 성적, 수능성적, 봉사활동, 대외활동, 수상경력 등을 학업 성취도, 커뮤니케이션 능력, 문제 해결력과 같은 더 함축적인 요약 특성으로 추출할 수 있다.
# #### 이처럼 차원 축소는 단순 데이터의 압축이 아닌 차원 축소를 통해 데이터를 잘 설명할 수 있는 잠재적인 요소를 추출하는 데에 있다.
# #### 대표적인 차원 축소 알고리즘은 PCA, SVD, NMF가 있다.

# %% [markdown]
# # 2. PCA(Principal Component Analysis)
# ## PCA 개요
# #### PCA는 여러 변수 간에 존재하는 상관관계를 이용해 이를 대표하는 주성분을 추출한 차원을 축소하는 기법이다.
# #### PCA로 차원을 축소할 때는 기존 데이터의 정보 유실이 최소화된다
# #### 가장 높은 분산을 가지는 데이터의 축을 찾아 이 축으로 차원을 축소하는데, 이것이 PCA의 주성분이 된다.

# %% [markdown]
# #### 키와 몸무게 2개의 피처를 가진 데이터 세트가 있다고 가정해보자
# ![image.png](attachment:image.png)
# #### 2개의 피처를 한 개의 주성분을 가진 데이터 세트로 차원 축소를 하자.
# #### 가장 큰 방향으로 축을 생성하고, 새롭게 생성된 축으로 데이터를 투영한다.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 요약하자면 PCA는 제일 먼저 가장 큰 데이터 변동성을 기반으로 첫 번째 벡터 축을 생성한다.
# #### 두 번째 축은 이 벡터 축에 직각이 되는 벡터(직교 벡터)를 축으로 한다.
# #### 세 번째 축은 다시 두 번째 축과 직각이 되는 벡터를 설정하는 방식으로 축을 생성한다.
# #### 이렇게 생성된 벡터 축에 원본 데이터를 투영하면 벡터 축의 개수만큼의 차원으로 원본 데이터가 차원 축소된다.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### PCA, 즉 주성분 분석은 원본 데이터의 피처 개수에 비해 매두 작은 주성분으로 원본 데이터의 총 변동성을 대부분 설명할 수 있는 분석법이다.

# %% [markdown]
# ## 선형대수 관점에서의 PCA
# #### 입력 데이터의 공분산 행렬을 고유값 분해하고, 이렇게 구한 고유벡터에 입력 데이터를 선형 변환하는 것이다.
# #### 이 고유벡터가 PCA의 주성분 벡터로서 입력 데이터의 분산이 큰 방향을 나타낸다.
# #### 고윳값은 바로 이 고유벡터의 크기를 나타내며, 동시에 입력 데이터의 분산을 나타낸다.

# %% [markdown]
# #### 일반적으로 선형 변환은 특정 벡터에 행렬 A를 곱해 새로운 벡터로 변환하는 것
# #### 이를 특정 벡터를 하나의 공간에서 다른 공간으로 투영하는 개념으로도 볼 수 있으면, 이 경우 이 행렬을 바로 공간으로 가정하는 것이다.

# %% [markdown]
# #### 보통 분산은 한 개의 특정한 변수의 데이터 변동을 의미하나, 공분산은 두 변수 간의 변동을 의미한다.
# #### 공분산 행렬은 여러 변수와 관련된 공분산을 포함하는 정방형 행렬이다.

# %% [markdown]
# #### 공분산 행렬은 정방행렬이며 대칭행렬이다.
# #### 정방행렬은 열과 행이 같은 행렬을 지칭하는데, 정방행렬 중에 대각원소를 중심으로 원소 값이 대칭 되는 행렬을 A^T = A인 행렬을 대칭행렬이라 한다.
# #### 이 대칭행렬은 고유값 분해와 관련해 매우 좋은 특성이 있는데, 항상 고유벡터를 직교하는 직교행렬로, 고유값을 정방 행렬로 대각화할 수 있다는 것이다.

# %% [markdown]
# ![image.png](attachment:image.png)
# #### 여기서 P는 n X n의 직교행렬이며, Σ는 n X n 정방행렬, P^t는 행렬 P의 전치 행렬이다.

# %% [markdown]
# ![image.png](attachment:image.png)
# #### 즉, 공분산 C는 고유벡터 직교 행렬 * 고유값 정방 행렬 * 고유벡터 직교 행렬의 전치 행렬로 분해된다.

# %% [markdown]
# #### 선형대수식까지 써가면서 강조하고 싶은 것은 "입력 데이터의 공분산 행렬이 고유벡터와 고유값으로 분해될 수 있으며, 이렇게 분해된 고유벡터를 이용해 입력 데이터를 선형 변환하는 방식이 PCA라는 것이다"
# #### 일반적인 PCA 수행 순서는 아래와 같다.
# #### 1. 입력 데이터 세트의 공분산 행렬을 생성
# #### 2. 공분산 행렬의 고유벡터와 고유값을 계산
# #### 3. 고유값이 가장 큰 순으로 K개(PCA 변환 차수만큼)만큼 고유벡터를 추출
# #### 4. 고유벡터를 이용해 새롭게 입력 데이터를 변환

# %% [markdown]
# #### 붓꽃(Iris) 데이터 세트의 4개의 속성을 2개의 PCA 차원으로 압축해 비교해보겠습니다.

# %%
from sklearn.datasets import load_iris
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

iris = load_iris()
columns = ['sepal_length', 'sepal_width',  'petal_length', 'petal_width']
irisDF = pd.DataFrame(iris.data, columns=columns)
irisDF['target'] = iris.target
irisDF.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  target
# 0           5.1          3.5           1.4          0.2       0
# 1           4.9          3.0           1.4          0.2       0
# 2           4.7          3.2           1.3          0.2       0
# 3           4.6          3.1           1.5          0.2       0
# 4           5.0          3.6           1.4          0.2       0

# %%
#setosa는 세모, versicolor는 네모, virginica는 동그라미로 표현
markers=['^', 's', 'o']

#setosa의 target 값은 0, versicolor는 1, virginica는 2. 각 target 별로 다른 shape으로 scatter plot 
for i, marker in enumerate(markers):
    x_axis_data = irisDF[irisDF['target']==i]['sepal_length']
    y_axis_data = irisDF[irisDF['target']==i]['sepal_width']
    plt.scatter(x_axis_data, y_axis_data, marker=marker,label=iris.target_names[i])

plt.legend()
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.show()

# %% [markdown]
# #### Setosa 품종의 경우 일정하게 분포되어 있지만, 다른 두 품정은 sepal 조건만으로 분류가 어렵다.
# #### 이제 PCA로 4개 속성을 2개로 압축한 뒤 2개의 PCA 속성으로 붓꽃 데이터의 품종 분포를 2차원으로 시각화하자

# %% [markdown]
# #### 붓꽃 데이터에 PCA를 적용하기 전에 개별 속성을 함께 스케일링해야 한다.
# #### PCA는 여러 속성의 값을 연산하기 때문에 동일한 스케일로 변환하는 것이 중요하다!
# #### StandardScaler를 이용해 평균 0, 분산 1인 표준 정규 분포로 변환하자

# %%
from sklearn.preprocessing import StandardScaler

iris_scaled = StandardScaler().fit_transform(irisDF.iloc[:, :-1])

# %% [markdown]
# #### 스케일링 적용된 데이터 세트에 PCA를 적용하자(4개 속성 -> 2개의 PCA 속성)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

pca.fit(iris_scaled)
iris_pca = pca.transform(iris_scaled)
print(iris_pca.shape)
# Out:
# (150, 2)

# %%
pca_columns = ['pca_comp_1', 'pca_comp_2']
irisDF_pca = pd.DataFrame(iris_pca, columns=pca_columns)
irisDF_pca['target'] = iris.target
irisDF_pca.head()
# Out:
#    pca_comp_1  pca_comp_2  target
# 0   -2.264703    0.480027       0
# 1   -2.080961   -0.674134       0
# 2   -2.364229   -0.341908       0
# 3   -2.299384   -0.597395       0
# 4   -2.389842    0.646835       0

# %%
#setosa를 세모, versicolor를 네모, virginica를 동그라미로 표시
markers=['^', 's', 'o']

#pca_component_1 을 x축, pc_component_2를 y축으로 scatter plot 수행. 
for i, marker in enumerate(markers):
    x_axis_data = irisDF_pca[irisDF_pca['target']==i]['pca_comp_1']
    y_axis_data = irisDF_pca[irisDF_pca['target']==i]['pca_comp_2']
    plt.scatter(x_axis_data, y_axis_data, marker=marker,label=iris.target_names[i])

plt.legend()
plt.xlabel('pca_comp_1')
plt.ylabel('pca_comp_2')
plt.show()

# %% [markdown]
# #### pca_comp1 축으로 비교적 잘 구분했다. 이는 pca_comp_1이 원본 데이터의 변동성을 잘 반영했기 때문이다.
# #### PCA Component 별로 원본 데이터의 변동성을 얼마나 반영하고 있는지 볼려면 PCA 객체의 explained_variance_ratio_ 속성을 확인하자.

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.72962445 0.22850762]

# %% [markdown]
# #### pca_comp_1은 전체 변동성의 약 72.9%, pca_comp_2는 22.8%를 차지한다.
# #### 즉, 2개의 요소로만 원본 데이터의 변동성을 95% 설명할 수 있다.
# #### 이번에는 원본과 PCA로 변환된 데이터 세트에 각각 분류를 적용하고 결과를 비교해보자

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
import numpy as np

rcf = RandomForestClassifier(random_state=156)
scores = cross_val_score(rcf, iris.data, iris.target, scoring='accuracy', cv=3)
print('PCA 변환 데이터 교차 검증 개별 정확도:',scores)
print('PCA 변환 데이터 평균 정확도:', np.mean(scores))
# Out:
# PCA 변환 데이터 교차 검증 개별 정확도: [0.98 0.94 0.96]
# PCA 변환 데이터 평균 정확도: 0.96

# %%
pca_X = irisDF_pca[['pca_comp_1', 'pca_comp_2']]
scores_pca = cross_val_score(rcf, pca_X, iris.target, scoring='accuracy', cv=3)
print('PCA 변환 데이터 교차 검증 개별 정확도:',scores_pca)
print('PCA 변환 데이터 평균 정확도:', np.mean(scores_pca))
# Out:
# PCA 변환 데이터 교차 검증 개별 정확도: [0.88 0.88 0.88]
# PCA 변환 데이터 평균 정확도: 0.88

# %% [markdown]
# #### 당연히 PCA 변환 차원 개수에 따라 예측 성능이 떨어질 수밖에 없다
# #### 하지만 4개의 속성을 2개로, 속성 개수가 50% 감소한 것을 고려한다면 PCA 변환 후에도 원본 데이터의 특성을 상당히 부분 유지하고 있음을 알 수 있다.

# %% [markdown]
# #### 다음은 좀 더 많은 데이터 세트를 적은 PCA 컴포넌트 기반으로 변환한 뒤 비교해보자
# #### UCI Machine Learning Repository에 있는 신용카드 고객 데이터 세트를 받자
# #### https://archive.ics.uci.edu/ml/machine-learning-databases/00350/

# %%
import pandas as pd

# pip install xlrd
df = pd.read_excel('C:\machine_learning_guide\DATA\\pca_credit_card.xls', header=1, sheet_name='Data').iloc[0:, 1:]
print(df.shape)
df.head()
# Out:
# (30000, 24)
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
# ...

# %% [markdown]
# #### 30000개의 레코드와 24개의 속성을 가진다.
# #### 'default payment next month'가 target 속성이고 다음달 연체여부로 연체일 경우 1, 아닐 경우 0이다.
# #### PAY 0 -> PAY 1로 변경하고, target 칼럼 명이 너무 길어서 default로 변경하자

# %%
df.rename(columns={'PAY_0':'PAY_1', 'default payment next month':'default'}, inplace=True)
y_target = df['default']
X_features = df.drop('default', axis=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

corr = X_features.corr()
plt.figure(figsize=(14,14))
sns.heatmap(corr, annot=True, fmt='.1g')
# Out:
# <Axes: >

# %% [markdown]
# #### BILL_AMT1 ~ BILL_AMT6 6개 속성끼리의 상관도가 0.9 이상으로 매우 높고, PAY_1 ~ PAY_6까지의 속성 역시 높다.
# #### 이렇게 높은 상관도를 가진 속성들을 PCA로 표현할 수 있다.
# #### BILL_AMT1 ~ BILL_AMT6를 2개의 컴포넌트로 PCA로 변환한 뒤 변동성을 explained_variance_ratio_ 속성으로 알아보자

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

cols_bill = ['BILL_AMT' + str(i) for i in range(1,7)]
print('대상 속성 명 :', cols_bill)

# 2개의 PCA 속성을 가진 PCA 객체 생성하고, explained_variance_ratio_ 계산을 위해 fit( ) 호출
scaler = StandardScaler()
df_cols_scaled = scaler.fit_transform(X_features[cols_bill])

pca = PCA(n_components=2)
pca.fit(df_cols_scaled)
print('PCA Component별 변동성:', pca.explained_variance_ratio_)
# Out:
# 대상 속성 명 : ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']
# PCA Component별 변동성: [0.90555253 0.0509867 ]

# %% [markdown]
# #### 단 2개의 컴포넌트만으로 6개 속성의 변동성을 95% 이상을 설명할 수 있으며, 첫 번째 컴포넌트로 90%를 설명할 수 있을만큼 6개의 속성의 상관도가 매우 높다.

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

rcf = RandomForestClassifier(n_estimators=300, random_state=156)
scores = cross_val_score(rcf, X_features, y_target, scoring='accuracy', cv=3)

print('CV=3 인 경우의 개별 Fold세트별 정확도:',scores)
print('평균 정확도:{0:.4f}'.format(np.mean(scores)))
# Out:
# CV=3 인 경우의 개별 Fold세트별 정확도: [0.8083 0.8196 0.8232]
# 평균 정확도:0.8170

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# 원본 데이터셋에 먼저 StandardScaler적용
scaler = StandardScaler()
df_scaled = scaler.fit_transform(X_features)

# 6개의 Component를 가진 PCA 변환을 수행하고 cross_val_score( )로 분류 예측 수행. 
pca = PCA(n_components=6)
df_pca = pca.fit_transform(df_scaled)
scores_pca = cross_val_score(rcf, df_pca, y_target, scoring='accuracy', cv=3)

print('CV=3 인 경우의 PCA 변환된 개별 Fold세트별 정확도:',scores_pca)
print('PCA 변환 데이터 셋 평균 정확도:{0:.4f}'.format(np.mean(scores_pca)))
# Out:
# CV=3 인 경우의 PCA 변환된 개별 Fold세트별 정확도: [0.7902 0.798  0.8014]
# PCA 변환 데이터 셋 평균 정확도:0.7965

# %% [markdown]
# #### 전체 23개 속성의 약 1/4 수준의 6개의 PCA 컴포넌트만으로 약간의 성능 저하로 좋은 성능을 보여줄 수 있다.
# #### PCA는 차원 축소를 통해 데이터를 쉽게 인지하는데 활용할 수 있지만, 이보다 더 활발하게 사용되는 분야는 컴퓨터 비전 분야이다. 특히 얼굴 인식의 Eigen-face
