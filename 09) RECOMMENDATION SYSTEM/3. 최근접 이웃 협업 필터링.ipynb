# %% [markdown]
# # 최근접 이웃 협업 필터링
# #### 사용자가 아이템에 매긴 평점 정보나 상품 구매 이력과 같은 사용자 행동 양식만을 기반으로 추천을 수행하는 것이 협업 필터링 방식이다.
# #### 주요 목표는 사용자-아이템 평점 매트릭스와 같은 축적된 사용자 행동 데이터를 기반으로 아직 평가하지 않은 아이템을 예측 평가하는 것이다.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 협업 필터링 기반은 최근접 이웃 방식과 잠재 요인 방식으로 나뉘며, 두 방식 모두 사용자-아이템 평점 행렬 데이터에만 의지하여 추천을 수행한다.
# #### 사용자-아이템 평점 행렬에서 행은 개별 사용자, 열은 개별 아이템으로 구성되며 다른 구조라면(레코드 형식) 변환에서 처리해야 한다.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 일반적으로 사용자-아이템 평점 행렬은 다차원 행렬이며, 사용자가 평점을 매기는 경우가 많지 않기 때문에 희소 행렬의 특징을 가지고 있다.
# #### 최근접 이웃 협업 필터링은 메모리 협업 필터링이라고도 하며, 사용자 기반과 아이템 기반으로 나뉠 수 있다.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 사용자 기반 최근접 이웃 방식은 특정 사용자와 유사한 다른 사용자를 TOP-N으로 선정해 해당 사용자들이 좋아는 아이템을 추천하는 방식이다.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 아이템 기반 최근접 이웃 방식은 아이템이 가지는 속성과는 상관없이 사용자들이 그 아이템을 좋아하는지/싫어하는지의 평가 척도가 유사한 아이템을 추천하는 알고리즘이다.
# #### 아래 예제에서, 다크 나이트의 평점 분포와 프로메테우스의 평점 분포가 유사하기 때문에, 다크 나이트를 재밌게 시청한 사용자 D에겐 스타워즈 보다는 프로메테우스를 추천하는 것이다.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 일반적으로 사용자 기반보다는 아이템 기반이 정확도가 더 높다.
# #### 그래서 최근접 이웃 협업 필터링은 대부분 아이템 기반의 알고리즘을 적용한다.
