# %% [markdown]
# # chapter 8. Text Analysis

# %% [markdown]
# ## Document Clustering

# %% [markdown]
# ### 문서 군집화 개념
#
# Document Clustering은 **비슷한 텍스트 구성의 문서를 군집화하는 것**이다. <br>
# 텍스트 분류 기반의 문서 분류와 유사하며 학습 데이터 세트가 필요 없는 비지도학습 기반으로 동작한다.

# %% [markdown]
# ### Opinon Review 데이터 세트를 이용한 문서 군집화 수행하기

# %%
import pandas as pd
import glob ,os
import warnings 
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 700)

path = r'data/opinosis dataset/topics'

# path로 지정한 디렉토리 밑에 있는 모든 .data 파일들의 파일명을 리스트로 취합한다. 
all_files = glob.glob(os.path.join(path, "*.data"))    
filename_list = []
opinion_text = []

# 개별 파일들의 파일명은 filename_list 리스트로 취합한다. 
# 개별 파일들의 파일내용은 DataFrame로딩 후 다시 string으로 변환하여 opinion_text 리스트로 취합한다. 
for file_ in all_files:
    # 개별 파일을 읽어서 DataFrame으로 생성 
    df = pd.read_table(file_,index_col = None, header = 0, encoding = 'latin1')

    
    # 절대경로로 주어진 file 명을 가공. 만일 Linux에서 수행시에는 아래 \\를 / 변경한다. 
    # 맨 마지막 .data 확장자도 제거
    filename_ = file_.split('\\')[-1]
    filename = filename_.split('.')[0]

    #파일명 리스트와 파일내용 리스트에 파일명과 파일 내용을 추가 
    filename_list.append(filename)
    opinion_text.append(df.to_string())

# 파일명 리스트와 파일내용 리스트를  DataFrame으로 생성
document_df = pd.DataFrame({'filename':filename_list, 'opinion_text':opinion_text})
document_df.head()
# Out:
#                                                      filename  \
# 0     data/opinosis dataset/topics/battery-life_ipod_nano_8gb
# 1  data/opinosis dataset/topics/gas_mileage_toyota_camry_2007
# 2        data/opinosis dataset/topics/room_holiday_inn_london
# 3    data/opinosis dataset/topics/location_holiday_inn_london
# 4    data/opinosis dataset/topics/staff_bestwestern_hotel_sfo
#
# ...

# %% [markdown]
# **TfidfVectorizer의 tokenizer 인자로 사용될 lemmatization 어근 변환 함수를 설정**

# %%
from nltk.stem import WordNetLemmatizer
import nltk
import string

remove_punct_dict = dict((ord(punct), None) for punct in string.punctuation)
lemmar = WordNetLemmatizer()

# 입력으로 들어온 token 단어들에 대해서 lemmatization 어근 변환 
def LemTokens(tokens):
    return [lemmar.lemmatize(token) for token in tokens]

# TfidfVectorizer 객체 생성 시 tokenizer인자로 해당 함수를 설정하여 lemmatization 적용
# 입력으로 문장을 받아서 stop words 제거 -> 소문자 변환 -> 단어 토큰화 -> lemmatization 어근 변환 
def LemNormalize(text):
    return LemTokens(nltk.word_tokenize(text.lower().translate(remove_punct_dict)))

# %% [markdown]
# **TF-IDF 기반 Vectorization 적용 및 KMeans 군집화 수행**
#
# TfidfVectorizer 생성자의 tokenizer인자로 위에서 생성 LemNormalize 함수 설정

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vect = TfidfVectorizer(tokenizer = LemNormalize, stop_words = 'english' , \
                             ngram_range = (1, 2), min_df = 0.05, max_df = 0.85 )

# opinion_text 컬럼값으로 feature vectorization 수행
feature_vect = tfidf_vect.fit_transform(document_df['opinion_text'])

# %%
from sklearn.cluster import KMeans

# 5개 집합으로 군집화 수행, 예제를 위해 동일한 클러스터링 결과 도출용 random_state = 0 
km_cluster = KMeans(n_clusters = 5, max_iter = 10000, random_state = 0)
km_cluster.fit(feature_vect)
cluster_label = km_cluster.labels_
cluster_centers = km_cluster.cluster_centers_

# %%
km_cluster.labels_
# Out:
# array([3, 0, 2, 4, 4, 1, 1, 3, 1, 3, 1, 3, 3, 4, 3, 3, 4, 4, 0, 1, 4, 1,
#        0, 0, 3, 3, 1, 4, 4, 0, 2, 2, 4, 1, 1, 0, 1, 3, 1, 4, 1, 1, 0, 0,
#        1, 0, 2, 0, 1, 4, 4], dtype=int32)

# %%
document_df['cluster_label'] = cluster_label
document_df.head()
# Out:
#                                                      filename  \
# 0     data/opinosis dataset/topics/battery-life_ipod_nano_8gb
# 1  data/opinosis dataset/topics/gas_mileage_toyota_camry_2007
# 2        data/opinosis dataset/topics/room_holiday_inn_london
# 3    data/opinosis dataset/topics/location_holiday_inn_london
# 4    data/opinosis dataset/topics/staff_bestwestern_hotel_sfo
#
# ...

# %%
document_df[document_df['cluster_label'] == 0].sort_values(by = 'filename')
# Out:
#                                                        filename  \
# 18       data/opinosis dataset/topics/comfort_honda_accord_2008
# 43       data/opinosis dataset/topics/comfort_toyota_camry_2007
# 1    data/opinosis dataset/topics/gas_mileage_toyota_camry_2007
# 45      data/opinosis dataset/topics/interior_honda_accord_2008
# 22      data/opinosis dataset/topics/interior_toyota_camry_2007
# 35       data/opinosis dataset/topics/mileage_honda_accord_2008
# 47   data/opinosis dataset/topics/performance_honda_accord_2008
# 42       data/opinosis dataset/topics/quality_toyota_camry_2007
# 29         data/opinosis dataset/topics/seats_honda_accord_2008
# 23  data/opinosis dataset/topics/transmission_toyota_camry_2007
#
# ...

# %%
document_df[document_df['cluster_label'] == 1].sort_values(by = 'filename')
# Out:
#                                                         filename  \
# 33    data/opinosis dataset/topics/accuracy_garmin_nuvi_255W_gps
# 26            data/opinosis dataset/topics/buttons_amazon_kindle
# 34  data/opinosis dataset/topics/directions_garmin_nuvi_255W_gps
# 48     data/opinosis dataset/topics/display_garmin_nuvi_255W_gps
# 36    data/opinosis dataset/topics/eyesight-issues_amazon_kindle
# 21                data/opinosis dataset/topics/features_windows7
# 44              data/opinosis dataset/topics/fonts_amazon_kindle
# 38         data/opinosis dataset/topics/navigation_amazon_kindle
# 41              data/opinosis dataset/topics/price_amazon_kindle
# 10   data/opinosis dataset/topics/satellite_garmin_nuvi_255W_gps
# 8       data/opinosis dataset/topics/screen_garmin_nuvi_255W_gps
# 6        data/opinosis dataset/topics/speed_garmin_nuvi_255W_gps
# 40                   data/opinosis dataset/topics/speed_windows7
# ...

# %%
document_df[document_df['cluster_label'] == 2].sort_values(by = 'filename')
# Out:
#                                                        filename  \
# 31  data/opinosis dataset/topics/bathroom_bestwestern_hotel_sfo
# 2          data/opinosis dataset/topics/room_holiday_inn_london
# 46     data/opinosis dataset/topics/rooms_bestwestern_hotel_sfo
# 30         data/opinosis dataset/topics/rooms_swissotel_chicago
#
# ...

# %%
document_df[document_df['cluster_label'] == 3].sort_values(by = 'filename')
# Out:
#                                                     filename  \
# 9    data/opinosis dataset/topics/battery-life_amazon_kindle
# 0    data/opinosis dataset/topics/battery-life_ipod_nano_8gb
# 11  data/opinosis dataset/topics/battery-life_netbook_1005ha
# 12      data/opinosis dataset/topics/keyboard_netbook_1005ha
# 15   data/opinosis dataset/topics/performance_netbook_1005ha
# 25         data/opinosis dataset/topics/screen_ipod_nano_8gb
# 37        data/opinosis dataset/topics/screen_netbook_1005ha
# 7      data/opinosis dataset/topics/size_asus_netbook_1005ha
# 24          data/opinosis dataset/topics/sound_ipod_nano_8gb
# 14          data/opinosis dataset/topics/video_ipod_nano_8gb
#
# ...

# %%
document_df[document_df['cluster_label'] == 4].sort_values(by = 'filename')
# Out:
#                                                         filename  \
# 17          data/opinosis dataset/topics/food_holiday_inn_london
# 32           data/opinosis dataset/topics/food_swissotel_chicago
# 49       data/opinosis dataset/topics/free_bestwestern_hotel_sfo
# 39   data/opinosis dataset/topics/location_bestwestern_hotel_sfo
# 3       data/opinosis dataset/topics/location_holiday_inn_london
# 50    data/opinosis dataset/topics/parking_bestwestern_hotel_sfo
# 28         data/opinosis dataset/topics/price_holiday_inn_london
# 16    data/opinosis dataset/topics/service_bestwestern_hotel_sfo
# 27       data/opinosis dataset/topics/service_holiday_inn_london
# 13  data/opinosis dataset/topics/service_swissotel_hotel_chicago
# 4       data/opinosis dataset/topics/staff_bestwestern_hotel_sfo
# 20          data/opinosis dataset/topics/staff_swissotel_chicago
#
# ...

# %%
from sklearn.cluster import KMeans

# 3개의 집합으로 군집화 
km_cluster = KMeans(n_clusters = 3, max_iter = 10000, random_state = 0)
km_cluster.fit(feature_vect)
cluster_label = km_cluster.labels_


# 소속 클러스터를 cluster_label 컬럼으로 할당하고 cluster_label 값으로 정렬
document_df['cluster_label'] = cluster_label
document_df.sort_values(by = 'cluster_label')
# Out:
#                                                         filename  \
# 50    data/opinosis dataset/topics/parking_bestwestern_hotel_sfo
# 27       data/opinosis dataset/topics/service_holiday_inn_london
# 28         data/opinosis dataset/topics/price_holiday_inn_london
# 30          data/opinosis dataset/topics/rooms_swissotel_chicago
# 20          data/opinosis dataset/topics/staff_swissotel_chicago
# 31   data/opinosis dataset/topics/bathroom_bestwestern_hotel_sfo
# 32           data/opinosis dataset/topics/food_swissotel_chicago
# 17          data/opinosis dataset/topics/food_holiday_inn_london
# 16    data/opinosis dataset/topics/service_bestwestern_hotel_sfo
# 13  data/opinosis dataset/topics/service_swissotel_hotel_chicago
# 49       data/opinosis dataset/topics/free_bestwestern_hotel_sfo
# 39   data/opinosis dataset/topics/location_bestwestern_hotel_sfo
# 46      data/opinosis dataset/topics/rooms_bestwestern_hotel_sfo
# ...

# %% [markdown]
# ### 군집별 핵심 단어 추출하기
#
# KMean 객체는 각 군집을 구성하는 단어 피처가 군집의 중심을 기준으로 얼마나 가깝게 위치해있는지 clusters_centers_ 라는 속성으로 제공한다.

# %%
feature_vect.shape
# Out:
# (51, 4611)

# %%
cluster_centers = km_cluster.cluster_centers_
print('cluster_centers shape :',cluster_centers.shape)
print(cluster_centers)
# Out:
# cluster_centers shape : (3, 4611)
# [[0.         0.00099499 0.00174637 ... 0.         0.00183397 0.00144581]
#  [0.01005322 0.         0.         ... 0.00706287 0.         0.        ]
#  [0.         0.00092551 0.         ... 0.         0.         0.        ]]

# %%
# 군집별 top n 핵심단어, 그 단어의 중심 위치 상대값, 대상 파일명들을 반환한다. 
def get_cluster_details(cluster_model, cluster_data, feature_names, clusters_num, top_n_features = 10):
    cluster_details = {}
    
    # cluster_centers array 의 값이 큰 순으로 정렬된 index 값을 반환
    # 군집 중심점(centroid)별 할당된 word 피처들의 거리값이 큰 순으로 값을 구하기 위함이다.  
    centroid_feature_ordered_ind = cluster_model.cluster_centers_.argsort()[:, ::-1]
    
    #개별 군집별로 iteration하면서 핵심단어, 그 단어의 중심 위치 상대값, 대상 파일명 입력
    for cluster_num in range(clusters_num):
        # 개별 군집별 정보를 담을 데이터 초기화
        cluster_details[cluster_num] = {}
        cluster_details[cluster_num]['cluster'] = cluster_num
        
        # cluster_centers_.argsort()[:,::-1] 로 구한 index 를 이용하여 top n 피처 단어를 구한다. 
        top_feature_indexes = centroid_feature_ordered_ind[cluster_num, :top_n_features]
        top_features = [ feature_names[ind] for ind in top_feature_indexes ]
        
        # top_feature_indexes를 이용해 해당 피처 단어의 중심 위치 상댓값 구한다. 
        top_feature_values = cluster_model.cluster_centers_[cluster_num, top_feature_indexes].tolist()
        
        # cluster_details 딕셔너리 객체에 개별 군집별 핵심 단어와 중심위치 상대값, 그리고 해당 파일명 입력
        cluster_details[cluster_num]['top_features'] = top_features
        cluster_details[cluster_num]['top_features_value'] = top_feature_values
        filenames = cluster_data[cluster_data['cluster_label'] == cluster_num]['filename']
        filenames = filenames.values.tolist()
        cluster_details[cluster_num]['filenames'] = filenames
        
    return cluster_details

# %%
def print_cluster_details(cluster_details):
    for cluster_num, cluster_detail in cluster_details.items():
        print('Cluster {0}'.format(cluster_num))
        print('Top features :', cluster_detail['top_features'])
        print('Reviews 파일명 :',cluster_detail['filenames'][:7])

# %%
feature_names = tfidf_vect.get_feature_names_out()
cluster_details = get_cluster_details(cluster_model = km_cluster, cluster_data = document_df, \
                                  feature_names = feature_names, clusters_num = 3, top_n_features = 10 )
print_cluster_details(cluster_details)
# Out:
# Cluster 0
# Top features : ['room', 'hotel', 'service', 'staff', 'food', 'location', 'bathroom', 'clean', 'price', 'parking']
# Reviews 파일명 : ['data/opinosis dataset/topics/room_holiday_inn_london', 'data/opinosis dataset/topics/location_holiday_inn_london', 'data/opinosis dataset/topics/staff_bestwestern_hotel_sfo', 'data/opinosis dataset/topics/service_swissotel_hotel_chicago', 'data/opinosis dataset/topics/service_bestwestern_hotel_sfo', 'data/opinosis dataset/topics/food_holiday_inn_london', 'data/opinosis dataset/topics/staff_swissotel_chicago']
# Cluster 1
# Top features : ['screen', 'battery', 'keyboard', 'battery life', 'life', 'kindle', 'direction', 'video', 'size', 'voice']
# ...
